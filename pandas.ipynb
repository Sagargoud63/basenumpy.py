# %%
import pandas as ss
s1=ss.series([11,22,33,44,55])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-57ee83c17327> in <module>
#       1 import pandas as ss
# ----> 2 s1=ss.series([11,22,33,44,55])
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
import pandas as pd

# %%
li=[11,22,22,33,44]

# %%
li
# Out:
# [11, 22, 22, 33, 44]

# %%
s1=pd.series(li)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-6e4995007bb6> in <module>
# ----> 1 s1=pd.series(li)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
s1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d0257f733e5e> in <module>
# ----> 1 s1
#
# NameError: name 's1' is not defined

# %%
s1=pd.Series(li)

# %%
s1
# Out:
# 0    11
# 1    22
# 2    22
# 3    33
# 4    44
# dtype: int64

# %%
a1=pd.Series([1,23,3,15,15])

# %%
a1
# Out:
# 0     1
# 1    23
# 2     3
# 3    15
# 4    15
# dtype: int64

# %%
a1=pd.Series([1,23,3,15,15],Index['a','b','s','s','e'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-98c4e6412aa1> in <module>
# ----> 1 a1=pd.Series([1,23,3,15,15],index['a','b','s','s','e'])
#
# NameError: name 'index' is not defined

# %%
a1=pd.Series([1,23,3,15,15],index['a','b','s','s','e'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-18da0e08f120> in <module>
# ----> 1 a1=pd.Series([1,23,3,15,15],Index['a','b','s','s','e'])
#
# NameError: name 'Index' is not defined

# %%
a1=pd.Series([1,23,3,15,15],index['a','b','s','s','e'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-98c4e6412aa1> in <module>
# ----> 1 a1=pd.Series([1,23,3,15,15],index['a','b','s','s','e'])
#
# NameError: name 'index' is not defined

# %%
a1=pd.Series([1,23,3,15,15],index=['a','b','s','s','e'])

# %%
a1
# Out:
# a     1
# b    23
# s     3
# s    15
# e    15
# dtype: int64

# %%
z=pd.series(['a':10,'d':52])
# Out:
#   File "<ipython-input-16-01100bb1dd9b>", line 1
#     z=pd.series(['a':10,'d':52])
#                     ^
# SyntaxError: invalid syntax

# %%
pd.series(['a':10,'d':52])
# Out:
#   File "<ipython-input-17-3ae7837b70bf>", line 1
#     pd.series(['a':10,'d':52])
#                   ^
# SyntaxError: invalid syntax

# %%
pd.series({'a':10,'d':52})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-ff092d5f1b79> in <module>
# ----> 1 pd.series({'a':10,'d':52})
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
pd.Series(['a':10,'d':52])
# Out:
#   File "<ipython-input-19-6a2d7bf13c60>", line 1
#     pd.Series(['a':10,'d':52])
#                   ^
# SyntaxError: invalid syntax

# %%
a1=pd.series(['a':10,'d':52])
# Out:
#   File "<ipython-input-20-01390d614ea9>", line 1
#     a1=pd.series(['a':10,'d':52])
#                      ^
# SyntaxError: invalid syntax

# %%
pd.series(['a'=10,'d'=52])
# Out:
#   File "<ipython-input-21-2492830e5bb4>", line 1
#     pd.series(['a'=10,'d'=52])
#                   ^
# SyntaxError: invalid syntax

# %%
import pandas as pand
a2=pand.Series({'x' :10})

# %%
a2
# Out:
# x    10
# dtype: int64

# %%
animals=pand.series({'q':qurrel,'w':warangal,'e':elephant,'r':rabbit})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-74e2a4bba00b> in <module>
# ----> 1 animals=pand.series({'q':qurrel,'w':warangal,'e':elephant,'r':rabbit})
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
animals=pand.series({'q':20,'w':32,'e':58,'r':582})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-652e599bc22d> in <module>
# ----> 1 animals=pand.series({'q':20,'w':32,'e':58,'r':582})
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
animals=pand.Series({'q':20,'w':32,'e':58,'r':582})

# %%
animal=pand.Series({'q':qurrel,'w':warangal,'e':elephant,'r':rabbit})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-51d984f246c7> in <module>
# ----> 1 animals=pand.Series({'q':qurrel,'w':warangal,'e':elephant,'r':rabbit})
#
# NameError: name 'qurrel' is not defined

# %%
animal=pand.Series({'w':warangal,'e':elephant,'r':rabbit})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-a1ad3733cbe3> in <module>
# ----> 1 animal=pand.Series({'q':qurrel,'w':warangal,'e':elephant,'r':rabbit})
#
# NameError: name 'qurrel' is not defined

# %%
animals=pand.Series({'q':20,'w':32,'e':58,'r':582})

# %%
animals
# Out:
# q     20
# w     32
# e     58
# r    582
# dtype: int64

# %%
ani=pand.Series({'w':warangal,'e':elephant,'r':rabbit})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-acec0a965b1d> in <module>
# ----> 1 ani=pand.Series({'w':warangal,'e':elephant,'r':rabbit})
#
# NameError: name 'warangal' is not defined

# %%
animals=pand.Series({'q':20,'w':32,'e':58,'r':582},index=['e','r','q','w'])

# %%
animals
# Out:
# e     58
# r    582
# q     20
# w     32
# dtype: int64

# %%
animals[2]
# Out:
# 20

# %%
animals[-1]
# Out:
# 32

# %%
animals[:1]
# Out:
# e    58
# dtype: int64

# %%
animals +250
# Out:
# e    308
# r    832
# q    270
# w    282
# dtype: int64

# %%
human=pand.Series([111,222,333444])

# %%
animals+human
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# e   NaN
# q   NaN
# r   NaN
# w   NaN
# dtype: float64

# %%
animals
# Out:
# e     58
# r    582
# q     20
# w     32
# dtype: int64

# %%
human
# Out:
# 0       111
# 1       222
# 2    333444
# dtype: int64

# %%
animals+human
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# e   NaN
# q   NaN
# r   NaN
# w   NaN
# dtype: float64

# %%
animals,human
# Out:
# (e     58
#  r    582
#  q     20
#  w     32
#  dtype: int64,
#  0       111
#  1       222
#  2    333444
#  dtype: int64)

# %%
animals+human
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# e   NaN
# q   NaN
# r   NaN
# w   NaN
# dtype: float64

# %%
n1=pand.Series([11,22,33])
n2=pand.Series([111,222,333])

# %%
n1,n2
# Out:
# (0    11
#  1    22
#  2    33
#  dtype: int64,
#  0    111
#  1    222
#  2    333
#  dtype: int64)

# %%
n1+n2
# Out:
# 0    122
# 1    244
# 2    366
# dtype: int64

# %%
n2=pand.Series([11,1,222,333])

# %%
n1,n2
# Out:
# (0    11
#  1    22
#  2    33
#  dtype: int64,
#  0     11
#  1      1
#  2    222
#  3    333
#  dtype: int64)

# %%
n1+n2
# Out:
# 0     22.0
# 1     23.0
# 2    255.0
# 3      NaN
# dtype: float64

# %%
import pandas as ok
f1=ok.Dataframe("name":{'sagar','raju'},"age":{'21','20'})
# Out:
#   File "<ipython-input-51-38354934fd8a>", line 2
#     f1=ok.Dataframe("name":{'sagar','raju'},"age":{'21','20'})
#                           ^
# SyntaxError: invalid syntax

# %%
import pandas as ok

# %%
f1=ok.DataFrame("name":{'sagar','raju'},"age":{'21','20'})
# Out:
#   File "<ipython-input-53-c1a6d92e8d68>", line 1
#     f1=ok.DataFrame("name":{'sagar','raju'},"age":{'21','20'})
#                           ^
# SyntaxError: invalid syntax

# %%
f1=ok.DataFrame('name':{'sagar','raju'},'age':{'21','20'})
# Out:
#   File "<ipython-input-54-e2a6ef2c1965>", line 1
#     f1=ok.DataFrame('name':{'sagar','raju'},'age':{'21','20'})
#                           ^
# SyntaxError: invalid syntax

# %%
f1=ok.DataFrame("name":{'sagar','raju'},"age":{'21','20'})
